# %%
# Utilisez pandas pour lire le fichier dans un Dataframe pandas.
import pandas as pd
import numpy as np
df =pd.read_csv("EDUCATION_ATTAINMENT.csv")
#df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ages[15-49]_All_grade1     626 non-null    float64
#  1   Ages[15-49]_All_grade2     626 non-null    float64
#  2   Ages[15-49]_All_grade3     626 non-null    float64
#  3   Ages[20-29]_All_grade1     626 non-null    float64
#  4   Ages[20-29]_All_grade2     626 non-null    float64
#  5   Ages[20-29]_All_grade3     626 non-null    float64
#  6   Ages[30-39]_All_grade1     625 non-null    float64
#  7   Ages[30-39]_All_grade2     625 non-null    float64
#  8   Ages[30-39]_All_grade3     625 non-null    float64
#  9   Ages[40-49]_All_grade1     625 non-null    float64
#  10  Ages[40-49]_All_grade2     625 non-null    float64
#  11  Ages[40-49]_All_grade3     625 non-null    float64
#  12  Ages[15-49]_Male_grade1    626 non-null    float64
# ...

# %%
df.describe()
# Out:
#        Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.873886                0.861490                0.837509
# std                  0.162624                0.166895                0.176555
# min                  0.251917                0.244071                0.233274
# 25%                  0.831791                0.803131                0.757465
# 50%                  0.948926                0.935167                0.909587
# 75%                  0.984447                0.980112                0.971166
# max                  1.000000                1.000000                1.000000
#
#        Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.823849                0.812738                0.789965
# ...

# %%
# voir les valeurs manquantes
df.isna().sum()
# Out:
# Ages[15-49]_All_grade1       0
# Ages[15-49]_All_grade2       0
# Ages[15-49]_All_grade3       0
# Ages[20-29]_All_grade1       0
# Ages[20-29]_All_grade2       0
# Ages[20-29]_All_grade3       0
# Ages[30-39]_All_grade1       1
# Ages[30-39]_All_grade2       1
# Ages[30-39]_All_grade3       1
# Ages[40-49]_All_grade1       1
# Ages[40-49]_All_grade2       1
# Ages[40-49]_All_grade3       1
# Ages[15-49]_Male_grade1      0
# Ages[15-49]_Male_grade2      0
# Ages[15-49]_Male_grade3      0
# Ages[20-29]_Male_grade1      0
# Ages[20-29]_Male_grade2      0
# Ages[20-29]_Male_grade3      0
# Ages[30-39]_Male_grade1      1
# Ages[30-39]_Male_grade2      1
# Ages[30-39]_Male_grade3      1
# Ages[40-49]_Male_grade1      1
# Ages[40-49]_Male_grade2      1
# Ages[40-49]_Male_grade3      1
# Ages[15-49]_Female_grade1    0
# Ages[15-49]_Female_grade2    0
# Ages[15-49]_Female_grade3    0
# Ages[20-29]_Female_grade1    0
# Ages[20-29]_Female_grade2    0
# Ages[20-29]_Female_grade3    0
# ...

# %%
# valeur manquante = true 
df.isna()
# Out:
#      Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# 0                     False                   False                   False
# 1                     False                   False                   False
# 2                     False                   False                   False
# 3                     False                   False                   False
# 4                     False                   False                   False
# ..                      ...                     ...                     ...
# 621                   False                   False                   False
# 622                   False                   False                   False
# 623                   False                   False                   False
# 624                   False                   False                   False
# 625                   False                   False                   False
#
# ...

# %%
#Utilisez ydata-profiling pour générer un rapport de l'ensemble de données fourni.
from ydata_profiling import ProfileReport

profile = ProfileReport(df)

# Sauvegarder le rapport dans un fichier HTML
profile.to_file('rapport.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#profile

# %%
#Recherchez les valeurs manquantes dans l'ensemble de données. 

""" Les catégories suivantes ne présentent pas de valeurs manquantes pour les groupes
d'âge : 
15-49 All-grade 1, 2, 3 
20-29 All-grade 1, 2, 3
Les catégories suivantes ont chacune 1 valeur manquante et représentent 0,2% de cellules manquantes :

30-39 All-grade 1, 2, 3
40-49 All-grade 1, 2, 3
15-49 Male-grade 1, 2, 3
30-39 Male-grade  1, 2, 3
Cela signifie que pour les groupes d'âge et les niveaux de grade mentionnés ci-dessus,
il y a quelques données manquantes, et ces données manquantes représentent environ 0,2% de l'ensemble des données de chaque
catégorie."""
# Out:
# " Les catégories suivantes ne présentent pas de valeurs manquantes pour les groupes\nd'âge : \n15-49 All-grade 1, 2, 3 \n20-29 All-grade 1, 2, 3\nLes catégories suivantes ont chacune 1 valeur manquante et représentent 0,2% de cellules manquantes :\n\n30-39 All-grade 1, 2, 3\n40-49 All-grade 1, 2, 3\n15-49 Male-grade 1, 2, 3\n30-39 Male-grade  1, 2, 3\nCela signifie que pour les groupes d'âge et les niveaux de grade mentionnés ci-dessus,\nil y a quelques données manquantes, et ces données manquantes représentent environ 0,2% de l'ensemble des données de chaque\ncatégorie."

# %%
#Examinez les corrélations entre les différentes colonnes de l’ensemble de données. 
#on examinant les données nous avons remarqué qu'il y'a pas assez de differences entre les colonnes

# %%
# Identifiez tous les autres modèles ou informations intéressants dans l'ensemble de données que vous
# pouvez découvrir grâce au rapport de profilage ydata.

"""1) les valeurs manquantes
2) les correlation entre les colonnes
3) les variables
4) les lignes en doubles """
# Out:
# '1) les valeurs manquantes\n2) les correlation entre les colonnes\n3) les variables\n4) les lignes en doubles '

# %% [markdown]
# Rédigez un résumé de vos résultats sur la base du rapport de profilage des données y.
#  Assurez-vous d'inclure tous les modèles ou informations intéressants que vous avez découverts dans l'ensemble de données.
#
#
# le ydata-profiling report nous affiche plusieurs aspects importants des données, notamment les statistiques descriptives,
# les valeurs manquantes, les corrélations et les outliers.
